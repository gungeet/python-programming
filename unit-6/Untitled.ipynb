# %%
import pandas as pd

# %%
water = pd.read_csv('water_quality.csv')

# %%
water.head()
# Out:
#    VMV_Code  National_Variable_Code   Variable_Common_Name  \
# 0        77                     635         NITROGEN TOTAL
# 1        78                     365  ALKALINITY TOTAL HCO3
# 2        79                    4541  CHLOROPHYLL CORRECTED
# 3        80                     414          CHLOROPHYLL A
# 4       157                     864              TURBIDITY
#
#   Variable_Common_Name_fr variable_type Variable_type_fr measurement_unit  \
# 0             AZOTE TOTAL      NITROGEN            AZOTE             MG/L
# 1   ALCALINIT TOTALE HCO3      PHYSICAL         PHYSIQUE             MG/L
# 2    CHLOROPHYLLE CORRIGE   CHLOROPHYLL     CHLOROPHYLLE              G/L
# 3          CHLOROPHYLLE A   CHLOROPHYLL     CHLOROPHYLLE              G/L
# 4                TURBIDIT      PHYSICAL         PHYSIQUE              NTU
#
#                     description                 Description_fr  \
# 0           MILLIGRAM PER LITER          MILLIGRAMME PAR LITRE
# ...
